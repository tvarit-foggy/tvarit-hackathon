# %%
# !pip install -U ray
# Out:
# Collecting ray
#   Downloading https://files.pythonhosted.org/packages/ea/ed/ff896981d4ac684614236f73c1a20cde5f6cb0e2a590c182f62b22706ab4/ray-1.0.0-cp36-cp36m-manylinux1_x86_64.whl (22.9MB)
#      |████████████████████████████████| 22.9MB 133kB/s
# Requirement already satisfied, skipping upgrade: jsonschema in /usr/local/lib/python3.6/dist-packages (from ray) (2.6.0)
# Collecting colorful
#   Downloading https://files.pythonhosted.org/packages/b0/8e/e386e248266952d24d73ed734c2f5513f34d9557032618c8910e605dfaf6/colorful-0.5.4-py2.py3-none-any.whl (201kB)
#      |████████████████████████████████| 204kB 42.7MB/s
# Requirement already satisfied, skipping upgrade: click>=7.0 in /usr/local/lib/python3.6/dist-packages (from ray) (7.1.2)
# Requirement already satisfied, skipping upgrade: google in /usr/local/lib/python3.6/dist-packages (from ray) (2.0.3)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from ray) (2.23.0)
# Requirement already satisfied, skipping upgrade: prometheus-client>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from ray) (0.8.0)
# Collecting aiohttp
#   Downloading https://files.pythonhosted.org/packages/7c/39/7eb5f98d24904e0f6d3edb505d4aa60e3ef83c0a58d6fe18244a51757247/aiohttp-3.6.2-cp36-cp36m-manylinux1_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 44.5MB/s
# Collecting aiohttp-cors
#   Downloading https://files.pythonhosted.org/packages/13/e7/e436a0c0eb5127d8b491a9b83ecd2391c6ff7dcd5548dfaec2080a2340fd/aiohttp_cors-0.7.0-py3-none-any.whl
# Collecting gpustat
#   Downloading https://files.pythonhosted.org/packages/b4/69/d8c849715171aeabd61af7da080fdc60948b5a396d2422f1f4672e43d008/gpustat-0.6.0.tar.gz (78kB)
#      |████████████████████████████████| 81kB 9.2MB/s
# Requirement already satisfied, skipping upgrade: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from ray) (3.12.4)
# Collecting opencensus
#   Downloading https://files.pythonhosted.org/packages/8a/9c/d40e3408e72d02612acf247d829e3fa9ff15c59f7ad81418ed79962f8681/opencensus-0.7.10-py2.py3-none-any.whl (126kB)
#      |████████████████████████████████| 133kB 44.7MB/s
# Collecting py-spy>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/8e/a7/ab45c9ee3c4654edda3efbd6b8e2fa4962226718a7e3e3be6e3926bf3617/py_spy-0.3.3-py2.py3-none-manylinux1_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 40.4MB/s
# Requirement already satisfied, skipping upgrade: filelock in /usr/local/lib/python3.6/dist-packages (from ray) (3.0.12)
# Collecting aioredis
#   Downloading https://files.pythonhosted.org/packages/b0/64/1b1612d0a104f21f80eb4c6e1b6075f2e6aba8e228f46f229cfd3fdac859/aioredis-1.3.1-py3-none-any.whl (65kB)
#      |████████████████████████████████| 71kB 7.8MB/s
# Requirement already satisfied, skipping upgrade: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from ray) (1.0.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.16 in /usr/local/lib/python3.6/dist-packages (from ray) (1.18.5)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/c9/dc/45cdef1b4d119eb96316b3117e6d5708a08029992b2fee2c143c7a0a5cc5/colorama-0.4.3-py2.py3-none-any.whl
# Collecting redis<3.5.0,>=3.3.2
#   Downloading https://files.pythonhosted.org/packages/f0/05/1fc7feedc19c123e7a95cfc9e7892eb6cdd2e5df4e9e8af6384349c1cc3d/redis-3.4.1-py2.py3-none-any.whl (71kB)
#      |████████████████████████████████| 71kB 8.5MB/s
# Requirement already satisfied, skipping upgrade: grpcio>=1.28.1 in /usr/local/lib/python3.6/dist-packages (from ray) (1.32.0)
# Requirement already satisfied, skipping upgrade: pyyaml in /usr/local/lib/python3.6/dist-packages (from ray) (3.13)
# Requirement already satisfied, skipping upgrade: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from google->ray) (4.6.3)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->ray) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->ray) (2.10)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->ray) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->ray) (2020.6.20)
# Collecting multidict<5.0,>=4.5
#   Downloading https://files.pythonhosted.org/packages/1a/95/f50352b5366e7d579e8b99631680a9e32e1b22adfa1629a8f23b1d22d5e2/multidict-4.7.6-cp36-cp36m-manylinux1_x86_64.whl (148kB)
#      |████████████████████████████████| 153kB 45.9MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/01/c9/379b807a9c298b9694d0af8ee4260be7d40ab1a11fb9d4ae9e70b1e69d96/yarl-1.6.0-cp36-cp36m-manylinux1_x86_64.whl (257kB)
#      |████████████████████████████████| 266kB 41.4MB/s
# Collecting idna-ssl>=1.0; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/46/03/07c4894aae38b0de52b52586b24bf189bb83e4ddabfe2e2c8f2419eec6f4/idna-ssl-1.1.0.tar.gz
# Requirement already satisfied, skipping upgrade: typing-extensions>=3.6.5; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (3.7.4.3)
# Collecting async-timeout<4.0,>=3.0
#   Downloading https://files.pythonhosted.org/packages/e1/1e/5a4441be21b0726c4464f3f23c8b19628372f606755a9d2e46c187e65ec4/async_timeout-3.0.1-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: attrs>=17.3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->ray) (20.2.0)
# Requirement already satisfied, skipping upgrade: six>=1.7 in /usr/local/lib/python3.6/dist-packages (from gpustat->ray) (1.15.0)
# Requirement already satisfied, skipping upgrade: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.6/dist-packages (from gpustat->ray) (7.352.0)
# Requirement already satisfied, skipping upgrade: psutil in /usr/local/lib/python3.6/dist-packages (from gpustat->ray) (5.4.8)
# Collecting blessings>=1.6
#   Downloading https://files.pythonhosted.org/packages/03/74/489f85a78247609c6b4f13733cbf3ba0d864b11aa565617b645d6fdf2a4a/blessings-1.7-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->ray) (50.3.0)
# Collecting opencensus-context==0.1.1
#   Downloading https://files.pythonhosted.org/packages/2b/b7/720d4507e97aa3916ac47054cd75490de6b6148c46d8c2c487638f16ad95/opencensus_context-0.1.1-py2.py3-none-any.whl
# Requirement already satisfied, skipping upgrade: google-api-core<2.0.0,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from opencensus->ray) (1.16.0)
# Collecting hiredis
#   Downloading https://files.pythonhosted.org/packages/ed/7d/6acf1c8d4f2fb327ff6feec000b4c56a20628fbe966a4c7cd16c0b80343c/hiredis-1.1.0-cp36-cp36m-manylinux2010_x86_64.whl (61kB)
#      |████████████████████████████████| 61kB 7.9MB/s
# Collecting contextvars; python_version >= "3.6" and python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/83/96/55b82d9f13763be9d672622e1b8106c85acb83edd7cc2fa5bc67cd9877e9/contextvars-2.4.tar.gz
# Requirement already satisfied, skipping upgrade: google-auth<2.0dev,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray) (1.17.2)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray) (1.52.0)
# Requirement already satisfied, skipping upgrade: pytz in /usr/local/lib/python3.6/dist-packages (from google-api-core<2.0.0,>=1.0.0->opencensus->ray) (2018.9)
# Collecting immutables>=0.9
#   Downloading https://files.pythonhosted.org/packages/99/e0/ea6fd4697120327d26773b5a84853f897a68e33d3f9376b00a8ff96e4f63/immutables-0.14-cp36-cp36m-manylinux1_x86_64.whl (98kB)
#      |████████████████████████████████| 102kB 11.5MB/s
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (4.6)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (0.2.8)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (4.1.1)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2.0dev,>=0.4.0->google-api-core<2.0.0,>=1.0.0->opencensus->ray) (0.4.8)
# Building wheels for collected packages: gpustat, idna-ssl, contextvars
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-0.6.0-cp36-none-any.whl size=12622 sha256=ee708f1a5fc8c0b9b9594032dc9565a75b1384bf451677d5213868f579fe4a31
#   Stored in directory: /root/.cache/pip/wheels/48/b4/d5/fb5b7f1d040f2ff20687e3bad6867d63155dbde5a7c10f4293
#   Building wheel for idna-ssl (setup.py) ... done
#   Created wheel for idna-ssl: filename=idna_ssl-1.1.0-cp36-none-any.whl size=3161 sha256=c5aa6c558b2a16d2e14268fcc120ba05dcd5c01c4779ed6d8aac9f79c0fe5157
#   Stored in directory: /root/.cache/pip/wheels/d3/00/b3/32d613e19e08a739751dd6bf998cfed277728f8b2127ad4eb7
#   Building wheel for contextvars (setup.py) ... done
#   Created wheel for contextvars: filename=contextvars-2.4-cp36-none-any.whl size=7666 sha256=d7517b9c987efc62a5ee964904b6c10a5832d2537cd686c2454320bcedd7edf6
#   Stored in directory: /root/.cache/pip/wheels/a5/7d/68/1ebae2668bda2228686e3c1cf16f2c2384cea6e9334ad5f6de
# Successfully built gpustat idna-ssl contextvars
# Installing collected packages: colorful, multidict, yarl, idna-ssl, async-timeout, aiohttp, aiohttp-cors, blessings, gpustat, immutables, contextvars, opencensus-context, opencensus, py-spy, hiredis, aioredis, colorama, redis, ray
# Successfully installed aiohttp-3.6.2 aiohttp-cors-0.7.0 aioredis-1.3.1 async-timeout-3.0.1 blessings-1.7 colorama-0.4.3 colorful-0.5.4 contextvars-2.4 gpustat-0.6.0 hiredis-1.1.0 idna-ssl-1.1.0 immutables-0.14 multidict-4.7.6 opencensus-0.7.10 opencensus-context-0.1.1 py-spy-0.3.3 ray-1.0.0 redis-3.4.1 yarl-1.6.0

# %%
import os
import time
import copy

from collections import OrderedDict

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import torchvision
from torchvision import datasets
from torchvision import transforms
from torch.utils.data.sampler import SubsetRandomSampler

from torch.utils.tensorboard import SummaryWriter

import matplotlib.pyplot as plt
import numpy as np

print(torch.cuda.is_available())
# Out:
# True

# %%
from functools import partial
import ray
from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

# %%
"""
Create train, valid, test iterators for CIFAR-10 [1].
Easily extended to MNIST, CIFAR-100 and Imagenet.
[1]: https://discuss.pytorch.org/t/feedback-on-pytorch-for-kaggle-competitions/2252/4
"""

def plot_images(images, cls_true, cls_pred=None):
    """
    Adapted from https://github.com/Hvass-Labs/TensorFlow-Tutorials/
    """
    fig, axes = plt.subplots(3, 3)

    for i, ax in enumerate(axes.flat):
        # plot img
        ax.imshow(images[i, :, :, :], interpolation='spline16')

        # show true & predicted classes
        cls_true_name = label_names[cls_true[i]]
        if cls_pred is None:
            xlabel = "{0} ({1})".format(cls_true_name, cls_true[i])
        else:
            cls_pred_name = label_names[cls_pred[i]]
            xlabel = "True: {0}\nPred: {1}".format(
                cls_true_name, cls_pred_name
            )
        ax.set_xlabel(xlabel)
        ax.set_xticks([])
        ax.set_yticks([])

    plt.show()

def get_train_valid_loader(data_dir,
                           batch_size,
                           augment,
                           random_seed,
                           valid_size=0.1,
                           shuffle=True,
                           show_sample=False,
                           num_workers=4,
                           pin_memory=False):
    """
    Utility function for loading and returning train and valid
    multi-process iterators over the CIFAR-10 dataset. A sample
    9x9 grid of the images can be optionally displayed.
    If using CUDA, num_workers should be set to 1 and pin_memory to True.
    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - augment: whether to apply the data augmentation scheme
      mentioned in the paper. Only applied on the train split.
    - random_seed: fix seed for reproducibility.
    - valid_size: percentage split of the training set used for
      the validation set. Should be a float in the range [0, 1].
    - shuffle: whether to shuffle the train/validation indices.
    - show_sample: plot 9x9 sample grid of the dataset.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.
    Returns
    -------
    - train_loader: training set iterator.
    - valid_loader: validation set iterator.
    """
    error_msg = "[!] valid_size should be in the range [0, 1]."
    assert ((valid_size >= 0) and (valid_size <= 1)), error_msg

    normalize = transforms.Normalize(
        mean=[0.4914, 0.4822, 0.4465],
        std=[0.2023, 0.1994, 0.2010],
    )

    # define transforms
    valid_transform = transforms.Compose([
            transforms.ToTensor(),
            normalize,
    ])
    if augment:
        train_transform = transforms.Compose([
            transforms.RandomCrop(32, padding=4),
            transforms.RandomHorizontalFlip(),
            transforms.ToTensor(),
            normalize,
        ])
    else:
        train_transform = transforms.Compose([
            transforms.ToTensor(),
            normalize,
        ])

    # load the dataset
    train_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=train_transform,
    )

    valid_dataset = datasets.CIFAR10(
        root=data_dir, train=True,
        download=True, transform=valid_transform,
    )

    num_train = len(train_dataset)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]
    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(
        train_dataset, batch_size=batch_size, sampler=train_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )
    valid_loader = torch.utils.data.DataLoader(
        valid_dataset, batch_size=batch_size, sampler=valid_sampler,
        num_workers=num_workers, pin_memory=pin_memory,
    )

    # visualize some images
    if show_sample:
        sample_loader = torch.utils.data.DataLoader(
            train_dataset, batch_size=9, shuffle=shuffle,
            num_workers=num_workers, pin_memory=pin_memory,
        )
        data_iter = iter(sample_loader)
        images, labels = data_iter.next()
        X = images.numpy().transpose([0, 2, 3, 1])
        plot_images(X, labels)

    loaders = {"Train":train_loader, "Valid":valid_loader} 
    dataset_sizes = {"Train": len(train_dataset), "Valid": len(train_dataset) * valid_size}
    return loaders, dataset_sizes


def get_test_loader(data_dir,
                    batch_size,
                    shuffle=True,
                    num_workers=4,
                    pin_memory=False):
    """
    Utility function for loading and returning a multi-process
    test iterator over the CIFAR-10 dataset.
    If using CUDA, num_workers should be set to 1 and pin_memory to True.
    Params
    ------
    - data_dir: path directory to the dataset.
    - batch_size: how many samples per batch to load.
    - shuffle: whether to shuffle the dataset after every epoch.
    - num_workers: number of subprocesses to use when loading the dataset.
    - pin_memory: whether to copy tensors into CUDA pinned memory. Set it to
      True if using GPU.
    Returns
    -------
    - data_loader: test set iterator.
    """
    normalize = transforms.Normalize(
        mean=[0.485, 0.456, 0.406],
        std=[0.229, 0.224, 0.225],
    )

    # define transform
    transform = transforms.Compose([
        transforms.ToTensor(),
        normalize,
    ])

    dataset = datasets.CIFAR10(
        root=data_dir, train=False,
        download=True, transform=transform,
    )

    data_loader = torch.utils.data.DataLoader(
        dataset, batch_size=batch_size, shuffle=shuffle,
        num_workers=num_workers, pin_memory=pin_memory,
    )
    loader = {"Test":data_loader}
    dataset_sizes = {"Test": len(dataset)}
    return loader, dataset_sizes

# %%
# Training the model
def train_model(model, dataloaders, dataset_sizes, criterion, optimizer, tb_logger, num_epochs, scheduler=None):
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0

    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        # Each epoch has a training and validation phase
        for phase in ['Train', 'Valid']:
            if phase == 'Train':
                if scheduler:
                    scheduler.step()
                model.train()  # Set model to training mode
            else:
                model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(DEVICE)
                labels = labels.to(DEVICE)
                # DEVICE --> where the computation is happening
                # Torch.dtypes --> cuda tensors, cpu tensors

                # zero the parameter gradients
                optimizer.zero_grad()

                # forward
                # track history if only in train
                with torch.set_grad_enabled(phase == 'Train'):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)

                    # backward + optimize only if in training phase
                    if phase == 'Train':
                        loss.backward()
                        optimizer.step()

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]

            #Log with Tensorboard
            if phase=='Train':
                tb_logger.add_scalar('train_Loss',float(epoch_loss), epoch+1)
                tb_logger.add_scalar('train_Accuracy', float(epoch_acc), epoch+1)
            elif phase=='Valid':
                tb_logger.add_scalar('valid_Loss',float(epoch_loss), epoch+1)
                tb_logger.add_scalar('valid_Accuracy', float(epoch_acc), epoch+1)

            print('{} Loss: {:.4f} Acc: {:.4f}'.format(
                phase, epoch_loss, epoch_acc))

            # deep copy the model
            if phase == 'Valid' and epoch_acc > best_acc:
                best_acc = epoch_acc
                best_model_wts = copy.deepcopy(model.state_dict())

    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))

    # load best model weights
    model.load_state_dict(best_model_wts)
    return best_model, epoch_loss, best_acc

def test_model(model, dataloaders, dataset_sizes, criterion):

    since = time.time()
    
    with torch.no_grad():
        for phase in ['Test']:
            model.eval()   # Set model to evaluate mode

            running_loss = 0.0
            running_corrects = 0

            # Iterate over data.
            for inputs, labels in dataloaders[phase]:
                inputs = inputs.to(DEVICE)
                labels = labels.to(DEVICE)

                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criterion(outputs, labels)

                # statistics
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / dataset_sizes[phase]
            epoch_acc = running_corrects.double() / dataset_sizes[phase]
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Test Acc: {:4f}'.format(epoch_acc))

    return epoch_acc

# %%
class Net(nn.Module):
    def __init__(self, c1=32, c2=64, c3=64, l1=64):
        super(Net, self).__init__()

        self.conv_block = nn.Sequential(OrderedDict([
          ('conv1', nn.Conv2d(3, c1, 3)),
          ('relu1', nn.ReLU()),
          ('pool1', nn.MaxPool2d(2,2)),
          ('conv2', nn.Conv2d(c1,c2,3)),
          ('relu2', nn.ReLU()),
          ('pool2', nn.MaxPool2d(2,2)),
          ('conv3', nn.Conv2d(c2,c2,3)),
          ('relu3', nn.ReLU()),
          ('flatten', nn.Flatten())
        ]))
        self.fc_block = nn.Sequential(OrderedDict([
          ('fc1', nn.Linear(1024, l1)),
          ('relu1', nn.ReLU()),
          ('fc2', nn.Linear(l1, 10))
        ]))

    def forward(self, x):
        x = self.conv_block(x)
        x = self.fc_block(x)
        return x

# %%
SEED=42
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

data_dir="./data"
batch_size=64
augment=False

valid_size=0.2
shuffle=True

learning_rate = 0.001

trainloaders, train_dataset_sizes = get_train_valid_loader(data_dir=data_dir, batch_size=batch_size,
                       augment=augment, random_seed=SEED, valid_size=valid_size,
                       shuffle=shuffle, show_sample=False, num_workers=1, pin_memory=True)
testloader, test_dataset_sizes = get_test_loader(data_dir=data_dir, batch_size=64, shuffle=False,
                             num_workers=1, pin_memory=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# Files already downloaded and verified

# %%
LOG_DIR = 'runs'
os.makedirs(LOG_DIR, exist_ok=True)

# %%
model = Net().to(DEVICE)

# %%
if DEVICE == "cuda":
    if torch.cuda.device_count() > 1:
        model = nn.DataParallel(model)
model = model.to(DEVICE)

# %%
def train(config, checkpoint_dir = None, data_dir="./data"):

    net = Net(config["c1"], config["c2"], config["c3"], config["l1"])

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    criterion = nn.CrossEntropyLoss()
    scheduler = None
    if config["optim"] == "SGD":
        optimizer = optim.SGD(net.parameters(), lr=config["lr"], momentum=0.9)
    elif config["optim"] == "Adam":
        optimizer = optim.Adam(model.parameters(), lr=config["lr"])

    # The `checkpoint_dir` parameter gets passed by Ray Tune when a checkpoint
    # should be restored.
    if checkpoint_dir:
        checkpoint = os.path.join(checkpoint_dir, "checkpoint")
        model_state, optimizer_state = torch.load(checkpoint)
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    augment=False
    valid_size=0.2
    shuffle=True
    trainloaders, train_dataset_sizes = get_train_valid_loader(data_dir=data_dir, batch_size=config["batchsize"],
                       augment=augment, random_seed=SEED, valid_size=valid_size,
                       shuffle=shuffle, show_sample=False, num_workers=8, pin_memory=True)
    testloader, test_dataset_sizes = get_test_loader(data_dir=data_dir, batch_size=64, shuffle=False,
                             num_workers=8, pin_memory=True)
    
    tb_logger = SummaryWriter(os.path.join(LOG_DIR,"test_exp2"))
    num_epochs = 10

    model, val_loss, val_acc = train_model(net, trainloaders, train_dataset_sizes, criterion, optimizer, tb_logger, num_epochs)
    
    test_acc = test_model(net, testloader, test_dataset_sizes, criterion)

    tune.report(loss=val_loss, accuracy=val_acc)
    tb_logger.close()

# %%
def main(num_samples=10, max_num_epochs=10, gpus_per_trial=0):
    data_dir = os.path.abspath("./data")
    # load_data(data_dir)  # Download data for all trials before starting the run
    config = {
        "c1": tune.choice([16, 32, 64]),
        "c2": tune.choice([32, 64, 128]),
        "c3": tune.choice([64, 128, 256]),        
        "l1": tune.sample_from(lambda _: 2 ** np.random.randint(2, 9)),
        "lr": tune.loguniform(1e-4, 1e-1),
        "batch_size": tune.choice([2, 4, 8, 16])
    }
    scheduler = ASHAScheduler(
        metric="loss",
        mode="min",
        max_t=max_num_epochs,
        grace_period=1,
        reduction_factor=2)
    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["loss", "accuracy", "training_iteration"])
    result = tune.run(
        partial(train, data_dir=data_dir),
        resources_per_trial={"cpu": 2, "gpu": gpus_per_trial},
        config=config,
        num_samples=num_samples,
        scheduler=scheduler,
        progress_reporter=reporter)

    best_trial = result.get_best_trial("loss", "min", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation loss: {}".format(
        best_trial.last_result["loss"]))
    print("Best trial final validation accuracy: {}".format(
        best_trial.last_result["accuracy"]))

    best_trained_model = Net(best_trial.config["l1"], best_trial.config["l2"])
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    checkpoint_path = os.path.join(best_trial.checkpoint.value, "checkpoint")

    model_state, optimizer_state = torch.load(checkpoint_path)
    best_trained_model.load_state_dict(model_state)

    testloader, test_dataset_sizes = get_test_loader(data_dir=data_dir, batch_size=64, shuffle=False,
                             num_workers=8, pin_memory=True)
    test_acc = test_model(best_trained_model, testloader, test_dataset_sizes, criterion)
    print("Best trial test set accuracy: {}".format(test_acc))

# %%
main()
# Out:
# 2020-10-10 12:13:17,426	WARNING experiment.py:256 -- No name detected on trainable. Using DEFAULT.
# 2020-10-10 12:13:17,428	INFO registry.py:65 -- Detected unknown callable for trainable. Converting to class.
# == Status ==
# Memory usage on this node: 2.8/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 2/2 CPUs, 0/1 GPUs, 0.0/7.13 GiB heap, 0.0/2.44 GiB objects (0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT
# Number of trials: 10 (9 PENDING, 1 RUNNING)
# +---------------------+----------+-------+--------------+------+------+------+------+-------------+
# | Trial name          | status   | loc   |   batch_size |   c1 |   c2 |   c3 |   l1 |          lr |
# |---------------------+----------+-------+--------------+------+------+------+------+-------------|
# | DEFAULT_fab5d_00000 | RUNNING  |       |            2 |   16 |  128 |  128 |   64 | 0.00398859  |
# | DEFAULT_fab5d_00001 | PENDING  |       |            8 |   32 |   64 |  128 |  128 | 0.0133473   |
# | DEFAULT_fab5d_00002 | PENDING  |       |            4 |   32 |  128 |   64 |    8 | 0.00536858  |
# | DEFAULT_fab5d_00003 | PENDING  |       |            4 |   32 |  128 |   64 |   16 | 0.000439499 |
# | DEFAULT_fab5d_00004 | PENDING  |       |            8 |   32 |  128 |  128 |  256 | 0.000833825 |
# | DEFAULT_fab5d_00005 | PENDING  |       |           16 |   64 |   32 |  128 |  128 | 0.00267381  |
# | DEFAULT_fab5d_00006 | PENDING  |       |            2 |   32 |  128 |  256 |    8 | 0.043687    |
# | DEFAULT_fab5d_00007 | PENDING  |       |            8 |   16 |  128 |   64 |    8 | 0.000353735 |
# | DEFAULT_fab5d_00008 | PENDING  |       |            4 |   32 |  128 |  128 |  256 | 0.0209075   |
# | DEFAULT_fab5d_00009 | PENDING  |       |            8 |   16 |   64 |  128 |   64 | 0.000617206 |
# +---------------------+----------+-------+--------------+------+------+------+------+-------------+
# (pid=1318) 2020-10-10 12:13:19,390	ERROR function_runner.py:233 -- Runner Thread raised error.
# (pid=1318) Traceback (most recent call last):
# (pid=1318)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1318)     self._entrypoint()
# (pid=1318)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1318)     self._status_reporter.get_checkpoint())
# (pid=1318)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1318)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1318)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1318) KeyError: 'optim'
# (pid=1318) Exception in thread Thread-2:
# (pid=1318) Traceback (most recent call last):
# (pid=1318)   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
# (pid=1318)     self.run()
# (pid=1318)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 246, in run
# (pid=1318)     raise e
# (pid=1318)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1318)     self._entrypoint()
# (pid=1318)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1318)     self._status_reporter.get_checkpoint())
# (pid=1318)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1318)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1318)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1318) KeyError: 'optim'
# (pid=1318)
# 2020-10-10 12:13:19,584	ERROR trial_runner.py:567 -- Trial DEFAULT_fab5d_00000: Error processing event.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trial_runner.py", line 515, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/ray_trial_executor.py", line 488, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/usr/local/lib/python3.6/dist-packages/ray/worker.py", line 1428, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train() (pid=1318, ip=172.28.0.2)
#   File "python/ray/_raylet.pyx", line 484, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 438, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trainable.py", line 336, in train
#     result = self.step()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 340, in step
#     self._report_thread_runner_error(block=True)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 459, in _report_thread_runner_error
#     .format(err_tb_str)))
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train() (pid=1318, ip=172.28.0.2)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
#     self._entrypoint()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
#     self._status_reporter.get_checkpoint())
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
#     output = train_func(config, checkpoint_dir=checkpoint_dir)
#   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# KeyError: 'optim'
# (pid=1338) 2020-10-10 12:13:21,543	ERROR function_runner.py:233 -- Runner Thread raised error.
# (pid=1338) Traceback (most recent call last):
# (pid=1338)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1338)     self._entrypoint()
# (pid=1338)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1338)     self._status_reporter.get_checkpoint())
# (pid=1338)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1338)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1338)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1338) KeyError: 'optim'
# (pid=1338) Exception in thread Thread-2:
# (pid=1338) Traceback (most recent call last):
# (pid=1338)   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
# (pid=1338)     self.run()
# (pid=1338)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 246, in run
# (pid=1338)     raise e
# (pid=1338)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1338)     self._entrypoint()
# (pid=1338)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1338)     self._status_reporter.get_checkpoint())
# (pid=1338)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1338)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1338)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1338) KeyError: 'optim'
# (pid=1338)
# 2020-10-10 12:13:21,738	ERROR trial_runner.py:567 -- Trial DEFAULT_fab5d_00001: Error processing event.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trial_runner.py", line 515, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/ray_trial_executor.py", line 488, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/usr/local/lib/python3.6/dist-packages/ray/worker.py", line 1428, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train() (pid=1338, ip=172.28.0.2)
#   File "python/ray/_raylet.pyx", line 484, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 438, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trainable.py", line 336, in train
#     result = self.step()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 340, in step
#     self._report_thread_runner_error(block=True)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 459, in _report_thread_runner_error
#     .format(err_tb_str)))
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train() (pid=1338, ip=172.28.0.2)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
#     self._entrypoint()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
#     self._status_reporter.get_checkpoint())
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
#     output = train_func(config, checkpoint_dir=checkpoint_dir)
#   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# KeyError: 'optim'
# (pid=1359) 2020-10-10 12:13:23,683	ERROR function_runner.py:233 -- Runner Thread raised error.
# (pid=1359) Traceback (most recent call last):
# (pid=1359)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1359)     self._entrypoint()
# (pid=1359)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1359)     self._status_reporter.get_checkpoint())
# (pid=1359)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1359)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1359)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1359) KeyError: 'optim'
# (pid=1359) Exception in thread Thread-2:
# (pid=1359) Traceback (most recent call last):
# (pid=1359)   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
# (pid=1359)     self.run()
# (pid=1359)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 246, in run
# (pid=1359)     raise e
# (pid=1359)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1359)     self._entrypoint()
# (pid=1359)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1359)     self._status_reporter.get_checkpoint())
# (pid=1359)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1359)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1359)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1359) KeyError: 'optim'
# (pid=1359)
# 2020-10-10 12:13:23,878	ERROR trial_runner.py:567 -- Trial DEFAULT_fab5d_00002: Error processing event.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trial_runner.py", line 515, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/ray_trial_executor.py", line 488, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/usr/local/lib/python3.6/dist-packages/ray/worker.py", line 1428, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train() (pid=1359, ip=172.28.0.2)
#   File "python/ray/_raylet.pyx", line 484, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 438, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trainable.py", line 336, in train
#     result = self.step()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 340, in step
#     self._report_thread_runner_error(block=True)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 459, in _report_thread_runner_error
#     .format(err_tb_str)))
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train() (pid=1359, ip=172.28.0.2)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
#     self._entrypoint()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
#     self._status_reporter.get_checkpoint())
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
#     output = train_func(config, checkpoint_dir=checkpoint_dir)
#   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# KeyError: 'optim'
# == Status ==
# Memory usage on this node: 2.9/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 0/2 CPUs, 0/1 GPUs, 0.0/7.13 GiB heap, 0.0/2.44 GiB objects (0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT
# Number of trials: 10 (3 ERROR, 7 PENDING)
# +---------------------+----------+-------+--------------+------+------+------+------+-------------+
# | Trial name          | status   | loc   |   batch_size |   c1 |   c2 |   c3 |   l1 |          lr |
# |---------------------+----------+-------+--------------+------+------+------+------+-------------|
# | DEFAULT_fab5d_00000 | ERROR    |       |            2 |   16 |  128 |  128 |   64 | 0.00398859  |
# | DEFAULT_fab5d_00001 | ERROR    |       |            8 |   32 |   64 |  128 |  128 | 0.0133473   |
# | DEFAULT_fab5d_00002 | ERROR    |       |            4 |   32 |  128 |   64 |    8 | 0.00536858  |
# | DEFAULT_fab5d_00003 | PENDING  |       |            4 |   32 |  128 |   64 |   16 | 0.000439499 |
# | DEFAULT_fab5d_00004 | PENDING  |       |            8 |   32 |  128 |  128 |  256 | 0.000833825 |
# | DEFAULT_fab5d_00005 | PENDING  |       |           16 |   64 |   32 |  128 |  128 | 0.00267381  |
# | DEFAULT_fab5d_00006 | PENDING  |       |            2 |   32 |  128 |  256 |    8 | 0.043687    |
# | DEFAULT_fab5d_00007 | PENDING  |       |            8 |   16 |  128 |   64 |    8 | 0.000353735 |
# | DEFAULT_fab5d_00008 | PENDING  |       |            4 |   32 |  128 |  128 |  256 | 0.0209075   |
# | DEFAULT_fab5d_00009 | PENDING  |       |            8 |   16 |   64 |  128 |   64 | 0.000617206 |
# +---------------------+----------+-------+--------------+------+------+------+------+-------------+
# Number of errored trials: 3
# +---------------------+--------------+-----------------------------------------------------------------------------------------------------------------------------------+
# | Trial name          |   # failures | error file                                                                                                                        |
# |---------------------+--------------+-----------------------------------------------------------------------------------------------------------------------------------|
# | DEFAULT_fab5d_00000 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00000_0_batch_size=2,c1=16,c2=128,c3=128,l1=64,lr=0.0039886_2020-10-10_12-13-17/error.txt |
# | DEFAULT_fab5d_00001 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00001_1_batch_size=8,c1=32,c2=64,c3=128,l1=128,lr=0.013347_2020-10-10_12-13-19/error.txt  |
# | DEFAULT_fab5d_00002 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00002_2_batch_size=4,c1=32,c2=128,c3=64,l1=8,lr=0.0053686_2020-10-10_12-13-21/error.txt   |
# +---------------------+--------------+-----------------------------------------------------------------------------------------------------------------------------------+
# (pid=1380) 2020-10-10 12:13:25,743	ERROR function_runner.py:233 -- Runner Thread raised error.
# (pid=1380) Traceback (most recent call last):
# (pid=1380)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1380)     self._entrypoint()
# (pid=1380)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1380)     self._status_reporter.get_checkpoint())
# (pid=1380)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1380)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1380)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1380) KeyError: 'optim'
# (pid=1380) Exception in thread Thread-2:
# (pid=1380) Traceback (most recent call last):
# (pid=1380)   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
# (pid=1380)     self.run()
# (pid=1380)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 246, in run
# (pid=1380)     raise e
# (pid=1380)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1380)     self._entrypoint()
# (pid=1380)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1380)     self._status_reporter.get_checkpoint())
# (pid=1380)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1380)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1380)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1380) KeyError: 'optim'
# (pid=1380)
# 2020-10-10 12:13:25,938	ERROR trial_runner.py:567 -- Trial DEFAULT_fab5d_00003: Error processing event.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trial_runner.py", line 515, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/ray_trial_executor.py", line 488, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/usr/local/lib/python3.6/dist-packages/ray/worker.py", line 1428, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train() (pid=1380, ip=172.28.0.2)
#   File "python/ray/_raylet.pyx", line 484, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 438, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trainable.py", line 336, in train
#     result = self.step()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 340, in step
#     self._report_thread_runner_error(block=True)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 459, in _report_thread_runner_error
#     .format(err_tb_str)))
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train() (pid=1380, ip=172.28.0.2)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
#     self._entrypoint()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
#     self._status_reporter.get_checkpoint())
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
#     output = train_func(config, checkpoint_dir=checkpoint_dir)
#   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# KeyError: 'optim'
# (pid=1400) 2020-10-10 12:13:27,888	ERROR function_runner.py:233 -- Runner Thread raised error.
# (pid=1400) Traceback (most recent call last):
# (pid=1400)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1400)     self._entrypoint()
# (pid=1400)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1400)     self._status_reporter.get_checkpoint())
# (pid=1400)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1400)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1400)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1400) KeyError: 'optim'
# (pid=1400) Exception in thread Thread-2:
# (pid=1400) Traceback (most recent call last):
# (pid=1400)   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
# (pid=1400)     self.run()
# (pid=1400)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 246, in run
# (pid=1400)     raise e
# (pid=1400)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1400)     self._entrypoint()
# (pid=1400)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1400)     self._status_reporter.get_checkpoint())
# (pid=1400)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1400)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1400)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1400) KeyError: 'optim'
# (pid=1400)
# 2020-10-10 12:13:28,080	ERROR trial_runner.py:567 -- Trial DEFAULT_fab5d_00004: Error processing event.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trial_runner.py", line 515, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/ray_trial_executor.py", line 488, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/usr/local/lib/python3.6/dist-packages/ray/worker.py", line 1428, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train() (pid=1400, ip=172.28.0.2)
#   File "python/ray/_raylet.pyx", line 484, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 438, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trainable.py", line 336, in train
#     result = self.step()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 340, in step
#     self._report_thread_runner_error(block=True)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 459, in _report_thread_runner_error
#     .format(err_tb_str)))
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train() (pid=1400, ip=172.28.0.2)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
#     self._entrypoint()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
#     self._status_reporter.get_checkpoint())
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
#     output = train_func(config, checkpoint_dir=checkpoint_dir)
#   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# KeyError: 'optim'
# (pid=1421) 2020-10-10 12:13:30,064	ERROR function_runner.py:233 -- Runner Thread raised error.
# (pid=1421) Traceback (most recent call last):
# (pid=1421)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1421)     self._entrypoint()
# (pid=1421)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1421)     self._status_reporter.get_checkpoint())
# (pid=1421)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1421)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1421)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1421) KeyError: 'optim'
# (pid=1421) Exception in thread Thread-2:
# (pid=1421) Traceback (most recent call last):
# (pid=1421)   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
# (pid=1421)     self.run()
# (pid=1421)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 246, in run
# (pid=1421)     raise e
# (pid=1421)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1421)     self._entrypoint()
# (pid=1421)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1421)     self._status_reporter.get_checkpoint())
# (pid=1421)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1421)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1421)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1421) KeyError: 'optim'
# (pid=1421)
# 2020-10-10 12:13:30,259	ERROR trial_runner.py:567 -- Trial DEFAULT_fab5d_00005: Error processing event.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trial_runner.py", line 515, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/ray_trial_executor.py", line 488, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/usr/local/lib/python3.6/dist-packages/ray/worker.py", line 1428, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train() (pid=1421, ip=172.28.0.2)
#   File "python/ray/_raylet.pyx", line 484, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 438, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trainable.py", line 336, in train
#     result = self.step()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 340, in step
#     self._report_thread_runner_error(block=True)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 459, in _report_thread_runner_error
#     .format(err_tb_str)))
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train() (pid=1421, ip=172.28.0.2)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
#     self._entrypoint()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
#     self._status_reporter.get_checkpoint())
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
#     output = train_func(config, checkpoint_dir=checkpoint_dir)
#   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# KeyError: 'optim'
# == Status ==
# Memory usage on this node: 2.9/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 0/2 CPUs, 0/1 GPUs, 0.0/7.13 GiB heap, 0.0/2.44 GiB objects (0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT
# Number of trials: 10 (6 ERROR, 4 PENDING)
# +---------------------+----------+-------+--------------+------+------+------+------+-------------+
# | Trial name          | status   | loc   |   batch_size |   c1 |   c2 |   c3 |   l1 |          lr |
# |---------------------+----------+-------+--------------+------+------+------+------+-------------|
# | DEFAULT_fab5d_00000 | ERROR    |       |            2 |   16 |  128 |  128 |   64 | 0.00398859  |
# | DEFAULT_fab5d_00001 | ERROR    |       |            8 |   32 |   64 |  128 |  128 | 0.0133473   |
# | DEFAULT_fab5d_00002 | ERROR    |       |            4 |   32 |  128 |   64 |    8 | 0.00536858  |
# | DEFAULT_fab5d_00003 | ERROR    |       |            4 |   32 |  128 |   64 |   16 | 0.000439499 |
# | DEFAULT_fab5d_00004 | ERROR    |       |            8 |   32 |  128 |  128 |  256 | 0.000833825 |
# | DEFAULT_fab5d_00005 | ERROR    |       |           16 |   64 |   32 |  128 |  128 | 0.00267381  |
# | DEFAULT_fab5d_00006 | PENDING  |       |            2 |   32 |  128 |  256 |    8 | 0.043687    |
# | DEFAULT_fab5d_00007 | PENDING  |       |            8 |   16 |  128 |   64 |    8 | 0.000353735 |
# | DEFAULT_fab5d_00008 | PENDING  |       |            4 |   32 |  128 |  128 |  256 | 0.0209075   |
# | DEFAULT_fab5d_00009 | PENDING  |       |            8 |   16 |   64 |  128 |   64 | 0.000617206 |
# +---------------------+----------+-------+--------------+------+------+------+------+-------------+
# Number of errored trials: 6
# +---------------------+--------------+-------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name          |   # failures | error file                                                                                                                          |
# |---------------------+--------------+-------------------------------------------------------------------------------------------------------------------------------------|
# | DEFAULT_fab5d_00000 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00000_0_batch_size=2,c1=16,c2=128,c3=128,l1=64,lr=0.0039886_2020-10-10_12-13-17/error.txt   |
# | DEFAULT_fab5d_00001 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00001_1_batch_size=8,c1=32,c2=64,c3=128,l1=128,lr=0.013347_2020-10-10_12-13-19/error.txt    |
# | DEFAULT_fab5d_00002 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00002_2_batch_size=4,c1=32,c2=128,c3=64,l1=8,lr=0.0053686_2020-10-10_12-13-21/error.txt     |
# | DEFAULT_fab5d_00003 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00003_3_batch_size=4,c1=32,c2=128,c3=64,l1=16,lr=0.0004395_2020-10-10_12-13-23/error.txt    |
# | DEFAULT_fab5d_00004 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00004_4_batch_size=8,c1=32,c2=128,c3=128,l1=256,lr=0.00083382_2020-10-10_12-13-25/error.txt |
# | DEFAULT_fab5d_00005 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00005_5_batch_size=16,c1=64,c2=32,c3=128,l1=128,lr=0.0026738_2020-10-10_12-13-28/error.txt  |
# +---------------------+--------------+-------------------------------------------------------------------------------------------------------------------------------------+
# (pid=1442) 2020-10-10 12:13:32,152	ERROR function_runner.py:233 -- Runner Thread raised error.
# (pid=1442) Traceback (most recent call last):
# (pid=1442)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1442)     self._entrypoint()
# (pid=1442)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1442)     self._status_reporter.get_checkpoint())
# (pid=1442)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1442)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1442)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1442) KeyError: 'optim'
# (pid=1442) Exception in thread Thread-2:
# (pid=1442) Traceback (most recent call last):
# (pid=1442)   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
# (pid=1442)     self.run()
# (pid=1442)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 246, in run
# (pid=1442)     raise e
# (pid=1442)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1442)     self._entrypoint()
# (pid=1442)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1442)     self._status_reporter.get_checkpoint())
# (pid=1442)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1442)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1442)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1442) KeyError: 'optim'
# (pid=1442)
# 2020-10-10 12:13:32,347	ERROR trial_runner.py:567 -- Trial DEFAULT_fab5d_00006: Error processing event.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trial_runner.py", line 515, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/ray_trial_executor.py", line 488, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/usr/local/lib/python3.6/dist-packages/ray/worker.py", line 1428, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train() (pid=1442, ip=172.28.0.2)
#   File "python/ray/_raylet.pyx", line 484, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 438, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trainable.py", line 336, in train
#     result = self.step()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 340, in step
#     self._report_thread_runner_error(block=True)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 459, in _report_thread_runner_error
#     .format(err_tb_str)))
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train() (pid=1442, ip=172.28.0.2)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
#     self._entrypoint()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
#     self._status_reporter.get_checkpoint())
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
#     output = train_func(config, checkpoint_dir=checkpoint_dir)
#   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# KeyError: 'optim'
# (pid=1462) 2020-10-10 12:13:34,339	ERROR function_runner.py:233 -- Runner Thread raised error.
# (pid=1462) Traceback (most recent call last):
# (pid=1462)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1462)     self._entrypoint()
# (pid=1462)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1462)     self._status_reporter.get_checkpoint())
# (pid=1462)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1462)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1462)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1462) KeyError: 'optim'
# (pid=1462) Exception in thread Thread-2:
# (pid=1462) Traceback (most recent call last):
# (pid=1462)   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
# (pid=1462)     self.run()
# (pid=1462)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 246, in run
# (pid=1462)     raise e
# (pid=1462)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1462)     self._entrypoint()
# (pid=1462)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1462)     self._status_reporter.get_checkpoint())
# (pid=1462)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1462)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1462)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1462) KeyError: 'optim'
# (pid=1462)
# 2020-10-10 12:13:34,534	ERROR trial_runner.py:567 -- Trial DEFAULT_fab5d_00007: Error processing event.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trial_runner.py", line 515, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/ray_trial_executor.py", line 488, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/usr/local/lib/python3.6/dist-packages/ray/worker.py", line 1428, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train() (pid=1462, ip=172.28.0.2)
#   File "python/ray/_raylet.pyx", line 484, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 438, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trainable.py", line 336, in train
#     result = self.step()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 340, in step
#     self._report_thread_runner_error(block=True)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 459, in _report_thread_runner_error
#     .format(err_tb_str)))
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train() (pid=1462, ip=172.28.0.2)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
#     self._entrypoint()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
#     self._status_reporter.get_checkpoint())
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
#     output = train_func(config, checkpoint_dir=checkpoint_dir)
#   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# KeyError: 'optim'
# (pid=1483) 2020-10-10 12:13:36,400	ERROR function_runner.py:233 -- Runner Thread raised error.
# (pid=1483) Traceback (most recent call last):
# (pid=1483)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1483)     self._entrypoint()
# (pid=1483)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1483)     self._status_reporter.get_checkpoint())
# (pid=1483)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1483)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1483)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1483) KeyError: 'optim'
# (pid=1483) Exception in thread Thread-2:
# (pid=1483) Traceback (most recent call last):
# (pid=1483)   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
# (pid=1483)     self.run()
# (pid=1483)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 246, in run
# (pid=1483)     raise e
# (pid=1483)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1483)     self._entrypoint()
# (pid=1483)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1483)     self._status_reporter.get_checkpoint())
# (pid=1483)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1483)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1483)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1483) KeyError: 'optim'
# (pid=1483)
# 2020-10-10 12:13:36,593	ERROR trial_runner.py:567 -- Trial DEFAULT_fab5d_00008: Error processing event.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trial_runner.py", line 515, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/ray_trial_executor.py", line 488, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/usr/local/lib/python3.6/dist-packages/ray/worker.py", line 1428, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train() (pid=1483, ip=172.28.0.2)
#   File "python/ray/_raylet.pyx", line 484, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 438, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trainable.py", line 336, in train
#     result = self.step()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 340, in step
#     self._report_thread_runner_error(block=True)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 459, in _report_thread_runner_error
#     .format(err_tb_str)))
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train() (pid=1483, ip=172.28.0.2)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
#     self._entrypoint()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
#     self._status_reporter.get_checkpoint())
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
#     output = train_func(config, checkpoint_dir=checkpoint_dir)
#   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# KeyError: 'optim'
# == Status ==
# Memory usage on this node: 2.9/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 0/2 CPUs, 0/1 GPUs, 0.0/7.13 GiB heap, 0.0/2.44 GiB objects (0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT
# Number of trials: 10 (9 ERROR, 1 PENDING)
# +---------------------+----------+-------+--------------+------+------+------+------+-------------+
# | Trial name          | status   | loc   |   batch_size |   c1 |   c2 |   c3 |   l1 |          lr |
# |---------------------+----------+-------+--------------+------+------+------+------+-------------|
# | DEFAULT_fab5d_00000 | ERROR    |       |            2 |   16 |  128 |  128 |   64 | 0.00398859  |
# | DEFAULT_fab5d_00001 | ERROR    |       |            8 |   32 |   64 |  128 |  128 | 0.0133473   |
# | DEFAULT_fab5d_00002 | ERROR    |       |            4 |   32 |  128 |   64 |    8 | 0.00536858  |
# | DEFAULT_fab5d_00003 | ERROR    |       |            4 |   32 |  128 |   64 |   16 | 0.000439499 |
# | DEFAULT_fab5d_00004 | ERROR    |       |            8 |   32 |  128 |  128 |  256 | 0.000833825 |
# | DEFAULT_fab5d_00005 | ERROR    |       |           16 |   64 |   32 |  128 |  128 | 0.00267381  |
# | DEFAULT_fab5d_00006 | ERROR    |       |            2 |   32 |  128 |  256 |    8 | 0.043687    |
# | DEFAULT_fab5d_00007 | ERROR    |       |            8 |   16 |  128 |   64 |    8 | 0.000353735 |
# | DEFAULT_fab5d_00008 | ERROR    |       |            4 |   32 |  128 |  128 |  256 | 0.0209075   |
# | DEFAULT_fab5d_00009 | PENDING  |       |            8 |   16 |   64 |  128 |   64 | 0.000617206 |
# +---------------------+----------+-------+--------------+------+------+------+------+-------------+
# Number of errored trials: 9
# +---------------------+--------------+-------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name          |   # failures | error file                                                                                                                          |
# |---------------------+--------------+-------------------------------------------------------------------------------------------------------------------------------------|
# | DEFAULT_fab5d_00000 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00000_0_batch_size=2,c1=16,c2=128,c3=128,l1=64,lr=0.0039886_2020-10-10_12-13-17/error.txt   |
# | DEFAULT_fab5d_00001 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00001_1_batch_size=8,c1=32,c2=64,c3=128,l1=128,lr=0.013347_2020-10-10_12-13-19/error.txt    |
# | DEFAULT_fab5d_00002 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00002_2_batch_size=4,c1=32,c2=128,c3=64,l1=8,lr=0.0053686_2020-10-10_12-13-21/error.txt     |
# | DEFAULT_fab5d_00003 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00003_3_batch_size=4,c1=32,c2=128,c3=64,l1=16,lr=0.0004395_2020-10-10_12-13-23/error.txt    |
# | DEFAULT_fab5d_00004 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00004_4_batch_size=8,c1=32,c2=128,c3=128,l1=256,lr=0.00083382_2020-10-10_12-13-25/error.txt |
# | DEFAULT_fab5d_00005 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00005_5_batch_size=16,c1=64,c2=32,c3=128,l1=128,lr=0.0026738_2020-10-10_12-13-28/error.txt  |
# | DEFAULT_fab5d_00006 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00006_6_batch_size=2,c1=32,c2=128,c3=256,l1=8,lr=0.043687_2020-10-10_12-13-30/error.txt     |
# | DEFAULT_fab5d_00007 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00007_7_batch_size=8,c1=16,c2=128,c3=64,l1=8,lr=0.00035373_2020-10-10_12-13-32/error.txt    |
# | DEFAULT_fab5d_00008 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00008_8_batch_size=4,c1=32,c2=128,c3=128,l1=256,lr=0.020908_2020-10-10_12-13-34/error.txt   |
# +---------------------+--------------+-------------------------------------------------------------------------------------------------------------------------------------+
# (pid=1503) 2020-10-10 12:13:38,580	ERROR function_runner.py:233 -- Runner Thread raised error.
# (pid=1503) Traceback (most recent call last):
# (pid=1503)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1503)     self._entrypoint()
# (pid=1503)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1503)     self._status_reporter.get_checkpoint())
# (pid=1503)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1503)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1503)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1503) KeyError: 'optim'
# (pid=1503) Exception in thread Thread-2:
# (pid=1503) Traceback (most recent call last):
# (pid=1503)   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
# (pid=1503)     self.run()
# (pid=1503)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 246, in run
# (pid=1503)     raise e
# (pid=1503)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
# (pid=1503)     self._entrypoint()
# (pid=1503)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
# (pid=1503)     self._status_reporter.get_checkpoint())
# (pid=1503)   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
# (pid=1503)     output = train_func(config, checkpoint_dir=checkpoint_dir)
# (pid=1503)   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# (pid=1503) KeyError: 'optim'
# (pid=1503)
# 2020-10-10 12:13:38,776	ERROR trial_runner.py:567 -- Trial DEFAULT_fab5d_00009: Error processing event.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trial_runner.py", line 515, in _process_trial
#     result = self.trial_executor.fetch_result(trial)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/ray_trial_executor.py", line 488, in fetch_result
#     result = ray.get(trial_future[0], timeout=DEFAULT_GET_TIMEOUT)
#   File "/usr/local/lib/python3.6/dist-packages/ray/worker.py", line 1428, in get
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(TuneError): ray::ImplicitFunc.train() (pid=1503, ip=172.28.0.2)
#   File "python/ray/_raylet.pyx", line 484, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 438, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/trainable.py", line 336, in train
#     result = self.step()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 340, in step
#     self._report_thread_runner_error(block=True)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 459, in _report_thread_runner_error
#     .format(err_tb_str)))
# ray.tune.error.TuneError: Trial raised an exception. Traceback:
# ray::ImplicitFunc.train() (pid=1503, ip=172.28.0.2)
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 227, in run
#     self._entrypoint()
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 290, in entrypoint
#     self._status_reporter.get_checkpoint())
#   File "/usr/local/lib/python3.6/dist-packages/ray/tune/function_runner.py", line 499, in _trainable_func
#     output = train_func(config, checkpoint_dir=checkpoint_dir)
#   File "<ipython-input-21-6d676047dfc4>", line 14, in train
# KeyError: 'optim'
# == Status ==
# Memory usage on this node: 2.9/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 0/2 CPUs, 0/1 GPUs, 0.0/7.13 GiB heap, 0.0/2.44 GiB objects (0/1.0 accelerator_type:K80)
# Result logdir: /root/ray_results/DEFAULT
# Number of trials: 10 (10 ERROR)
# +---------------------+----------+-------+--------------+------+------+------+------+-------------+
# | Trial name          | status   | loc   |   batch_size |   c1 |   c2 |   c3 |   l1 |          lr |
# |---------------------+----------+-------+--------------+------+------+------+------+-------------|
# | DEFAULT_fab5d_00000 | ERROR    |       |            2 |   16 |  128 |  128 |   64 | 0.00398859  |
# | DEFAULT_fab5d_00001 | ERROR    |       |            8 |   32 |   64 |  128 |  128 | 0.0133473   |
# | DEFAULT_fab5d_00002 | ERROR    |       |            4 |   32 |  128 |   64 |    8 | 0.00536858  |
# | DEFAULT_fab5d_00003 | ERROR    |       |            4 |   32 |  128 |   64 |   16 | 0.000439499 |
# | DEFAULT_fab5d_00004 | ERROR    |       |            8 |   32 |  128 |  128 |  256 | 0.000833825 |
# | DEFAULT_fab5d_00005 | ERROR    |       |           16 |   64 |   32 |  128 |  128 | 0.00267381  |
# | DEFAULT_fab5d_00006 | ERROR    |       |            2 |   32 |  128 |  256 |    8 | 0.043687    |
# | DEFAULT_fab5d_00007 | ERROR    |       |            8 |   16 |  128 |   64 |    8 | 0.000353735 |
# | DEFAULT_fab5d_00008 | ERROR    |       |            4 |   32 |  128 |  128 |  256 | 0.0209075   |
# | DEFAULT_fab5d_00009 | ERROR    |       |            8 |   16 |   64 |  128 |   64 | 0.000617206 |
# +---------------------+----------+-------+--------------+------+------+------+------+-------------+
# Number of errored trials: 10
# +---------------------+--------------+-------------------------------------------------------------------------------------------------------------------------------------+
# | Trial name          |   # failures | error file                                                                                                                          |
# |---------------------+--------------+-------------------------------------------------------------------------------------------------------------------------------------|
# | DEFAULT_fab5d_00000 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00000_0_batch_size=2,c1=16,c2=128,c3=128,l1=64,lr=0.0039886_2020-10-10_12-13-17/error.txt   |
# | DEFAULT_fab5d_00001 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00001_1_batch_size=8,c1=32,c2=64,c3=128,l1=128,lr=0.013347_2020-10-10_12-13-19/error.txt    |
# | DEFAULT_fab5d_00002 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00002_2_batch_size=4,c1=32,c2=128,c3=64,l1=8,lr=0.0053686_2020-10-10_12-13-21/error.txt     |
# | DEFAULT_fab5d_00003 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00003_3_batch_size=4,c1=32,c2=128,c3=64,l1=16,lr=0.0004395_2020-10-10_12-13-23/error.txt    |
# | DEFAULT_fab5d_00004 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00004_4_batch_size=8,c1=32,c2=128,c3=128,l1=256,lr=0.00083382_2020-10-10_12-13-25/error.txt |
# | DEFAULT_fab5d_00005 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00005_5_batch_size=16,c1=64,c2=32,c3=128,l1=128,lr=0.0026738_2020-10-10_12-13-28/error.txt  |
# | DEFAULT_fab5d_00006 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00006_6_batch_size=2,c1=32,c2=128,c3=256,l1=8,lr=0.043687_2020-10-10_12-13-30/error.txt     |
# | DEFAULT_fab5d_00007 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00007_7_batch_size=8,c1=16,c2=128,c3=64,l1=8,lr=0.00035373_2020-10-10_12-13-32/error.txt    |
# | DEFAULT_fab5d_00008 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00008_8_batch_size=4,c1=32,c2=128,c3=128,l1=256,lr=0.020908_2020-10-10_12-13-34/error.txt   |
# | DEFAULT_fab5d_00009 |            1 | /root/ray_results/DEFAULT/DEFAULT_fab5d_00009_9_batch_size=8,c1=16,c2=64,c3=128,l1=64,lr=0.00061721_2020-10-10_12-13-36/error.txt   |
# +---------------------+--------------+-------------------------------------------------------------------------------------------------------------------------------------+
# ---------------------------------------------------------------------------
# TuneError                                 Traceback (most recent call last)
# <ipython-input-29-263240bbee7e> in <module>()
# ----> 1 main()
#
# <ipython-input-26-b8e0e4c82991> in main(num_samples, max_num_epochs, gpus_per_trial)
#      25         num_samples=num_samples,
#      26         scheduler=scheduler,
# ---> 27         progress_reporter=reporter)
#      28
#      29     best_trial = result.get_best_trial("loss", "min", "last")
#
# /usr/local/lib/python3.6/dist-packages/ray/tune/tune.py in run(run_or_experiment, name, metric, mode, stop, time_budget_s, config, resources_per_trial, num_samples, local_dir, search_alg, scheduler, keep_checkpoints_num, checkpoint_score_attr, checkpoint_freq, checkpoint_at_end, verbose, progress_reporter, loggers, log_to_file, trial_name_creator, trial_dirname_creator, sync_config, export_formats, max_failures, fail_fast, restore, server_port, resume, queue_trials, reuse_actors, trial_executor, raise_on_failed_trial, ray_auto_init, run_errored_only, global_checkpoint_period, with_server, upload_dir, sync_to_cloud, sync_to_driver, sync_on_checkpoint)
#     425     if incomplete_trials:
#     426         if raise_on_failed_trial:
# --> 427             raise TuneError("Trials did not complete", incomplete_trials)
#     428         else:
#     429             logger.error("Trials did not complete: %s", incomplete_trials)
#
# TuneError: ('Trials did not complete', [DEFAULT_fab5d_00000, DEFAULT_fab5d_00001, DEFAULT_fab5d_00002, DEFAULT_fab5d_00003, DEFAULT_fab5d_00004, DEFAULT_fab5d_00005, DEFAULT_fab5d_00006, DEFAULT_fab5d_00007, DEFAULT_fab5d_00008, DEFAULT_fab5d_00009])
